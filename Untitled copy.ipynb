# %%
import torch

# %%
from torch import nn

# %%
import torchvision

# %%
# from torchvision.io import read_image

# %%
# img = read_image("data/oldman/1.jpg")

# %%
from matplotlib import image
from matplotlib import pyplot

img = image.imread("data/oldman/1.jpg")

# %%
import torchvision.transforms.functional as F
F.to_pil_image(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
tranform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0,0,0), (0.5, 0.5, 0.5))
    
])

# %%
tranform(img).shape
# Out:
# torch.Size([3, 720, 1280])

# %%
F.to_pil_image(tranform(img))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
# Python program to read
# image using matplotlib
 
# importing matplotlib modules
# import matplotlib.image as mpimg
# import matplotlib.pyplot as plt
 
# # Read Images
# img = mpimg.imread("img (877).jpg")

# Output Images
# plt.imshow(img)

# %%
img.shape, tranform(img).shape
# Out:
# ((720, 1280, 3), torch.Size([3, 720, 1280]))

# %%
img_torch = tranform(img)

# %%
F.to_pil_image(img_torch[0])
# Out:
# <PIL.Image.Image image mode=L size=1280x720>

# %%
# the probelm to face here is that the images (normally) have w*h*3 shape
# but for convlutions we want sth of size 3*w*h

# %%
# img_torch = torch.zeros((3,720,1280))

# %%
# img [:,:, 0].shape, img_torch[0,:,:].shape

# %%
# img_torch[0,:,:] = torch.tensor(img [:,:, 0])
# img_torch[1,:,:] = torch.tensor(img [:,:, 1])
# img_torch[2,:,:] = torch.tensor(img [:,:, 2])

# %%
img_torch.shape
# Out:
# torch.Size([3, 720, 1280])

# %%
# img_torch = img_torch.reshape(1,3,720,1280)

# %%
# img_torch = torch.tensor(img)

# %%
CNN = nn.Sequential(
    nn.Conv2d(in_channels=3,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2)  ,
    nn.Conv2d(in_channels=10,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2),
    nn.Conv2d(in_channels=10,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2),
    nn.Conv2d(in_channels=10,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2),
    nn.Conv2d(in_channels=10,out_channels=1, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2),
    nn.Flatten(start_dim=1),
    nn.Linear(880,100),
    
    nn.Linear(100,4*9*16),
    # nn.ReLU(True),
    # nn.Linear(270, ),
    nn.Unflatten(dim=1, unflattened_size=(4,  9,16)),
    nn.ConvTranspose2d(in_channels=4, out_channels=8, kernel_size=(5,5), stride=1, padding=2),
    nn.Upsample(scale_factor=(4,4), mode='bilinear'),
    
    nn.ConvTranspose2d(in_channels=8, out_channels=8, kernel_size=(5,5), stride=1, padding=2),
    nn.Upsample(scale_factor=(4,4), mode='bilinear'),
    
    nn.ConvTranspose2d(in_channels=8, out_channels=1, kernel_size=(5,5), stride=1, padding=2),
    nn.Upsample(scale_factor=(5,5), mode='bilinear'),

    
    
)

# %%
CNN = CNN.float()

# %%
CNNed_img = CNN(img_torch.float())
CNNed_img.shape
# Out:
# torch.Size([1, 1, 720, 1280])

# %%
# plt.imshow(CNNed_img.
#            reshape(CNNed_img.shape[2],CNNed_img.shape[3])
#            .detach().numpy())

# %%
CNN = nn.Sequential(
    nn.Conv2d(in_channels=3,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2)  
    # nn.Conv2d(in_channels=3,out_channels=10, kernel_size=(3,3), padding=1) ,
    # nn.MaxPool2d(kernel_size=(2,2), stride=2)
    # nn.Conv2d(in_channels=3,out_channels=10, kernel_size=(3,3), padding=1) ,


    
)

# %%
# CNN(img1)
# CNN(img2)

# %%
# to do:
# add ReLU after each conv

# %%
CNN_enc = nn.Sequential(
    nn.Conv2d(in_channels=3,out_channels=10, kernel_size=(3,3), padding=1) ,
    # nn.ReLU(),
    nn.MaxPool2d(kernel_size=(2,2), stride=2)  ,
    nn.ReLU(),
    nn.Conv2d(in_channels=10,out_channels=10, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(2,2), stride=2),
    nn.ReLU(),
    nn.Conv2d(in_channels=10,out_channels=1, kernel_size=(3,3), padding=1) ,
    nn.MaxPool2d(kernel_size=(5,5), stride=2, padding=2),
    nn.ReLU(),
    
    # nn.Conv2d(in_channels=10,out_channels=10, kernel_size=(3,3), padding=1) ,
    # nn.MaxPool2d(kernel_size=(2,2), stride=2),
    # nn.ReLU(),
    # nn.Conv2d(in_channels=10,out_channels=1, kernel_size=(3,3), padding=1) ,
    # nn.MaxPool2d(kernel_size=(2,2), stride=2),
    # nn.ReLU(),
    # nn.Flatten(start_dim=1),
    # nn.Linear(144000, 8800)
    nn.Flatten(start_dim=1),
    nn.ReLU(),

    nn.Linear(90*160,100),
    nn.ReLU(),

    nn.Linear(100,100),
    nn.ReLU(),

)

# %%
CNN_enc(img_torch).shape
# Out:
# torch.Size([1, 100])

# %%
CNN_dec = nn.Sequential(
    nn.Linear(100+100,4*9*16),
    # nn.ReLU(True),
    # nn.Linear(270, ),
    nn.Unflatten(dim=1, unflattened_size=(4,  9,16)),
    nn.ConvTranspose2d(in_channels=4, out_channels=8, kernel_size=(5,5), stride=1, padding=2),
    nn.ReLU(),

    nn.Upsample(scale_factor=(4,4), mode='bilinear'),
    
    nn.ConvTranspose2d(in_channels=8, out_channels=8, kernel_size=(5,5), stride=1, padding=2),
    nn.ReLU(),
    
    nn.Upsample(scale_factor=(4,4), mode='bilinear'),
    
    nn.ConvTranspose2d(in_channels=8, out_channels=3, kernel_size=(5,5), stride=1, padding=2),
    nn.ReLU(),
    
    nn.Upsample(scale_factor=(5,5), mode='bilinear'),
)

# %%
CNN_dec(torch.rand((1, 200))).shape
# Out:
# torch.Size([1, 3, 720, 1280])

# %%
# CNN_dec(CNN_enc(torch.cat((img_torch, img_torch), axis=1)))

# %%
CNN_enc(img_torch).shape
# Out:
# torch.Size([1, 100])

# %%
img1_cnn_enc = CNN_enc(img_torch)
img2_cnn_enc = CNN_enc(img_torch)
torch.cat((img1_cnn_enc, img2_cnn_enc), axis=1).shape
# Out:
# torch.Size([1, 200])

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()        
        # self.img1 = img1
        # self.img2 = img2

    def forward(self, img1, img2):
        img1_cnn_enc = CNN_enc(img1)
        img2_cnn_enc = CNN_enc(img2)

        inp = torch.cat((img1_cnn_enc, img2_cnn_enc), axis=1)
        return CNN_dec(inp)

# %%
img_torch.shape
# Out:
# torch.Size([3, 720, 1280])

# %%
net = Net()

# %%
net(img_torch, img_torch).shape
# Out:
# torch.Size([1, 3, 720, 1280])

# %%
# Python program to read
# image using matplotlib
 
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread("img (877).jpg")

# %%
import os
from os import listdir
 
img = []
folder_dir = "data/oldman"
for images_name in os.listdir(folder_dir):
 
    # check if the image ends with png or jpg or jpeg
    if (images_name.endswith(".png") or images_name.endswith(".jpg")):
        # display
        img.append(mpimg.imread(folder_dir+"/"+images_name))
        # print(images_name)

# %%
img[0].shape
# Out:
# (720, 1280, 3)

# %%
# img = torch.tensor(img)

# %%
# img.shape

# %%
img_torch = torch.zeros((len(img), 3,720,1280))
# img_torch = torch.zeros((3,720,1280))
for i in range(len(img)):
    img_torch[i, :,:,:] = tranform(img[i])

# %%
img_torch.shape
# Out:
# torch.Size([85, 3, 720, 1280])

# %%
# img[0]
import numpy as np

# %%
# plt.imshow(img[80].reshape(720, 1280, 3))

# %%
net.parameters()
# Out:
# <generator object Module.parameters at 0x7fb0265a4f90>

# %%
lr= 0.003
params_to_optimize = [{'params':net.parameters()}]

optim = torch.optim.SGD(params_to_optimize, lr=lr, weight_decay=1e-05)

# %%
net(img_torch[0].reshape(1,3, 720, 1280), 
    img_torch[2].reshape(1,3, 720, 1280)
   ).shape
# Out:
# torch.Size([1, 3, 720, 1280])

# %%
# for i in range(0,10,2):
#     print(i)

# %%
def train_epoch(loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    net.train()
    for epoch in range(20):
        train_loss = []
        # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
        for i in range(0, len(img)-2, 2): 
            
            # two points are inputs
            y_hat = net(img_torch[i].reshape(1,3, 720, 1280), 
                        img_torch[i+2].reshape(1,3, 720, 1280)
                       )
            
            # middle point
            y = img_torch[i+1].reshape(1,3, 720, 1280)
            
            # Evaluate loss
            loss = loss_fn(y, y_hat)
            print(loss)

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss.append(loss.detach().cpu().numpy())
            # Print batch loss
        print(f' epoch: {epoch}:  {np.mean(train_loss)}')
        

    return np.mean(train_loss)

# %%
loss_fn = torch.nn.MSELoss()

# %%
loss_fn(img_torch[0].reshape(1,3, 720, 1280), 
        img_torch[2].reshape(1,3, 720, 1280)
        )
# Out:
# tensor(0.0073)

# %%
train_epoch(
            loss_fn=loss_fn, 
            optimizer=optim)
# Out:
# tensor(1.1113, grad_fn=<MseLossBackward0>)
# tensor(1.1132, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1119, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1130, grad_fn=<MseLossBackward0>)
# tensor(1.1095, grad_fn=<MseLossBackward0>)
# tensor(1.1128, grad_fn=<MseLossBackward0>)
# tensor(1.1127, grad_fn=<MseLossBackward0>)
# tensor(1.1232, grad_fn=<MseLossBackward0>)
# tensor(1.1212, grad_fn=<MseLossBackward0>)
# tensor(1.1280, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1236, grad_fn=<MseLossBackward0>)
# tensor(1.1230, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1105, grad_fn=<MseLossBackward0>)
# tensor(1.1284, grad_fn=<MseLossBackward0>)
# tensor(1.1269, grad_fn=<MseLossBackward0>)
# tensor(1.1097, grad_fn=<MseLossBackward0>)
# tensor(1.1226, grad_fn=<MseLossBackward0>)
# tensor(1.1149, grad_fn=<MseLossBackward0>)
# tensor(1.1246, grad_fn=<MseLossBackward0>)
# tensor(1.1146, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1228, grad_fn=<MseLossBackward0>)
# tensor(1.1096, grad_fn=<MseLossBackward0>)
# tensor(1.1192, grad_fn=<MseLossBackward0>)
# tensor(1.1057, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1138, grad_fn=<MseLossBackward0>)
# tensor(1.1101, grad_fn=<MseLossBackward0>)
# tensor(1.1073, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1314, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1276, grad_fn=<MseLossBackward0>)
# tensor(1.1111, grad_fn=<MseLossBackward0>)
# tensor(1.1048, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1311, grad_fn=<MseLossBackward0>)
#  epoch: 0:  1.1166937351226807
# tensor(1.1113, grad_fn=<MseLossBackward0>)
# tensor(1.1132, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1119, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1130, grad_fn=<MseLossBackward0>)
# tensor(1.1095, grad_fn=<MseLossBackward0>)
# tensor(1.1128, grad_fn=<MseLossBackward0>)
# tensor(1.1127, grad_fn=<MseLossBackward0>)
# tensor(1.1232, grad_fn=<MseLossBackward0>)
# tensor(1.1212, grad_fn=<MseLossBackward0>)
# tensor(1.1280, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1236, grad_fn=<MseLossBackward0>)
# tensor(1.1230, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1105, grad_fn=<MseLossBackward0>)
# tensor(1.1284, grad_fn=<MseLossBackward0>)
# tensor(1.1269, grad_fn=<MseLossBackward0>)
# tensor(1.1097, grad_fn=<MseLossBackward0>)
# tensor(1.1226, grad_fn=<MseLossBackward0>)
# tensor(1.1149, grad_fn=<MseLossBackward0>)
# tensor(1.1246, grad_fn=<MseLossBackward0>)
# tensor(1.1146, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1228, grad_fn=<MseLossBackward0>)
# tensor(1.1096, grad_fn=<MseLossBackward0>)
# tensor(1.1192, grad_fn=<MseLossBackward0>)
# tensor(1.1057, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1138, grad_fn=<MseLossBackward0>)
# tensor(1.1101, grad_fn=<MseLossBackward0>)
# tensor(1.1073, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1314, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1276, grad_fn=<MseLossBackward0>)
# tensor(1.1111, grad_fn=<MseLossBackward0>)
# tensor(1.1048, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1311, grad_fn=<MseLossBackward0>)
#  epoch: 1:  1.1166937351226807
# tensor(1.1113, grad_fn=<MseLossBackward0>)
# tensor(1.1132, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1119, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1130, grad_fn=<MseLossBackward0>)
# tensor(1.1095, grad_fn=<MseLossBackward0>)
# tensor(1.1128, grad_fn=<MseLossBackward0>)
# tensor(1.1127, grad_fn=<MseLossBackward0>)
# tensor(1.1232, grad_fn=<MseLossBackward0>)
# tensor(1.1212, grad_fn=<MseLossBackward0>)
# tensor(1.1280, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1236, grad_fn=<MseLossBackward0>)
# tensor(1.1230, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1105, grad_fn=<MseLossBackward0>)
# tensor(1.1284, grad_fn=<MseLossBackward0>)
# tensor(1.1269, grad_fn=<MseLossBackward0>)
# tensor(1.1097, grad_fn=<MseLossBackward0>)
# tensor(1.1226, grad_fn=<MseLossBackward0>)
# tensor(1.1149, grad_fn=<MseLossBackward0>)
# tensor(1.1246, grad_fn=<MseLossBackward0>)
# tensor(1.1146, grad_fn=<MseLossBackward0>)
# tensor(1.1290, grad_fn=<MseLossBackward0>)
# tensor(1.1228, grad_fn=<MseLossBackward0>)
# tensor(1.1096, grad_fn=<MseLossBackward0>)
# tensor(1.1192, grad_fn=<MseLossBackward0>)
# tensor(1.1057, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1138, grad_fn=<MseLossBackward0>)
# tensor(1.1101, grad_fn=<MseLossBackward0>)
# tensor(1.1073, grad_fn=<MseLossBackward0>)
# tensor(1.1185, grad_fn=<MseLossBackward0>)
# tensor(1.1314, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# tensor(1.1276, grad_fn=<MseLossBackward0>)
# tensor(1.1111, grad_fn=<MseLossBackward0>)
# tensor(1.1048, grad_fn=<MseLossBackward0>)
# tensor(1.1093, grad_fn=<MseLossBackward0>)
# tensor(1.1311, grad_fn=<MseLossBackward0>)
#  epoch: 2:  1.1166937351226807
# tensor(1.1113, grad_fn=<MseLossBackward0>)
# tensor(1.1132, grad_fn=<MseLossBackward0>)
# tensor(1.1131, grad_fn=<MseLossBackward0>)
# tensor(1.1056, grad_fn=<MseLossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 train_epoch(
#       2             loss_fn=loss_fn,
#       3             optimizer=optim)
#
# Cell In[71], line 10, in train_epoch(loss_fn, optimizer)
#       6 # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
#       7 for i in range(0, len(img)-2, 2):
#       8
#       9     # two points are inputs
# ---> 10     y_hat = net(img_torch[i].reshape(1,3, 720, 1280),
#      11                 img_torch[i+2].reshape(1,3, 720, 1280)
#      12                )
#      14     # middle point
#      15     y = img_torch[i+1].reshape(1,3, 720, 1280)
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[41], line 8, in Net.forward(self, img1, img2)
#       7 def forward(self, img1, img2):
# ----> 8     img1_cnn_enc = CNN_enc(img1)
#       9     img2_cnn_enc = CNN_enc(img2)
#      11     inp = torch.cat((img1_cnn_enc, img2_cnn_enc), axis=1)
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/s/lib/python3.10/site-packages/torch/nn/modules/conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
sample = net(img_torch[0].reshape(1,3, 720, 1280), 
                        img_torch[2].reshape(1,3, 720, 1280)
                       ).reshape(3, 720, 1280)

# %%
sample.shape
# Out:
# torch.Size([3, 720, 1280])

# %%
F.to_pil_image(sample)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
